# %% [markdown]
# <a href="https://colab.research.google.com/github/naomigom47/programing/blob/main/2_1_%EC%9E%85%EB%A0%A5%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input('가격(원):')
b = input('할인율(%):')
c = a * b / 100
print(f'할인받은 가격은 {c:0.0f}원 입니다.')
